# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('Sample_superstore.csv',encoding='windows-1254')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df1=df.drop(['Postal Code'],inplace=True,axis=1)

# %%
df.shape
# Out:
# (9994, 20)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.corr()
# Out:
#             Row ID     Sales  Quantity  Discount    Profit
# Row ID    1.000000 -0.001359 -0.004016  0.013480  0.012497
# Sales    -0.001359  1.000000  0.200795 -0.028190  0.479064
# Quantity -0.004016  0.200795  1.000000  0.008623  0.066253
# Discount  0.013480 -0.028190  0.008623  1.000000 -0.219487
# Profit    0.012497  0.479064  0.066253 -0.219487  1.000000

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
df['Region'].value_counts()
# Out:
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: Region, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
df.groupby('Sub-Category')['Sales'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
df.groupby('Sub-Category')['Profit'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Sub-Category'>

# %%
df.groupby('Region')['Sales'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
df.groupby('Region')['Profit'].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='Region'>

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df.cov()
# Out:
#                 Row ID          Sales    Quantity   Discount        Profit
# Row ID    8.324169e+06   -2442.819776  -25.782598   8.029358   8446.585421
# Sales    -2.442820e+03  388434.455308  278.459923  -3.627228  69944.096586
# Quantity -2.578260e+01     278.459923    4.951113   0.003961     34.534769
# Discount  8.029358e+00      -3.627228    0.003961   0.042622    -10.615173
# Profit    8.446585e+03   69944.096586   34.534769 -10.615173  54877.798055

# %%
# Data visualization

# %%
# Univariate analysis

# Histogram for numerical columns (e.g., Sales, Quantity, Discount, Profit)
plt.figure(figsize=(10, 6))
sns.histplot(df['Sales'], bins=30, kde=True)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar plot for categorical columns (e.g., Category, Sub-Category, Segment)
plt.figure(figsize=(10, 6))
sns.countplot(x='Category', data=df)
plt.title('Count of Products in Each Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Furniture'),
#   Text(1, 0, 'Office Supplies'),
#   Text(2, 0, 'Technology')])

# %%
# Bivariate analysis

# Scatter plot to visualize the relationship between Sales and Profit
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title('Sales vs. Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
# Out:
# Text(0, 0.5, 'Profit')

# %%
# Box plot to compare Profit across different Categories
plt.figure(figsize=(10, 6))
sns.boxplot(x='Category', y='Profit', data=df)
plt.title('Profit by Category')
plt.xlabel('Category')
plt.ylabel('Profit')
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2]),
#  [Text(0, 0, 'Furniture'),
#   Text(1, 0, 'Office Supplies'),
#   Text(2, 0, 'Technology')])

# %%
# Multivariate analysis

# Pair plot to visualize relationships between numerical variables (e.g., Sales, Quantity, Discount, Profit)
sns.pairplot(df[['Sales', 'Quantity', 'Discount', 'Profit']])

# %%
# Heatmap to visualize correlations between numerical variables
plt.figure(figsize=(10, 6))
sns.heatmap(df[['Sales', 'Quantity', 'Discount', 'Profit']].corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
# Filter rows with negative profit
negative_profit_df = df[df['Profit'] < 0]

# %%
negative_profit_df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 14        15  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 15        16  US-2015-118983  11/22/2015  11/26/2015  Standard Class
# 23        24  US-2017-156909   7/16/2017   7/18/2017    Second Class
# 27        28  US-2015-150630   9/17/2015   9/21/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9920    9921  CA-2016-149272   3/15/2016   3/19/2016  Standard Class
# 9921    9922  CA-2014-111360  11/24/2014  11/30/2014  Standard Class
# 9931    9932  CA-2015-104948  11/13/2015  11/17/2015  Standard Class
# 9937    9938  CA-2016-164889    6/3/2016    6/6/2016    Second Class
# 9962    9963  CA-2015-168088   3/19/2015   3/22/2015     First Class
#
#      Customer ID     Customer Name      Segment        Country  \
# 3       SO-20335    Sean O'Donnell     Consumer  United States
# ...

# %%
# Group by sub-category and calculate the average profit and sales for each sub-category
subcat_profit_sales = negative_profit_df.groupby('Sub-Category')['Profit', 'Sales'].mean().reset_index()
# Out:
# C:\Users\Dell\AppData\Local\Temp/ipykernel_3364/1342085734.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   subcat_profit_sales = negative_profit_df.groupby('Sub-Category')['Profit', 'Sales'].mean().reset_index()

# %%
# Sort sub-categories by average profit in ascending order
subcat_profit_sales_sorted = subcat_profit_sales.sort_values(by='Profit', ascending=True)

# %%
# Plot the sub-categories with negative profit and their average sales
plt.figure(figsize=(12, 6))
sns.barplot(x='Profit', y='Sub-Category', data=subcat_profit_sales_sorted, color='red')
plt.title('Sub-Categories with Negative Profit and their Average Sales')
plt.xlabel('Average Profit')
plt.ylabel('Sub-Category')
plt.show()

# %%
df['Discount'].unique()
# Out:
# array([0.  , 0.45, 0.2 , 0.8 , 0.3 , 0.5 , 0.7 , 0.6 , 0.32, 0.1 , 0.4 ,
#        0.15])

# %%
#Cost Analysis
# Calculate the total cost of goods sold (COGS) for each sub-category with negative profit
subcat_negative_profit_cogs = negative_profit_df.groupby('Sub-Category')['Profit'].sum()

# %%
#Pricing Analysis
# Calculate the average discount for each sub-category with negative profit
subcat_negative_profit_avg_discount = negative_profit_df.groupby('Sub-Category')['Discount'].mean()

# %%
#Sales and Demand Analysis
# Calculate the average sales for each sub-category with negative profit
subcat_negative_profit_avg_sales = negative_profit_df.groupby('Sub-Category')['Sales'].mean()

# %%
# Visualization
plt.figure(figsize=(12, 6))
sns.barplot(x='Sub-Category', y='Sales', data=negative_profit_df, estimator=lambda x: x.mean(), ci=None, color='blue', label='Average Sales')
sns.barplot(x='Sub-Category', y='Profit', data=negative_profit_df, estimator=lambda x: x.mean(), ci=None, color='red', label='Average Profit')
plt.title('Average Sales and Profit for Sub-Categories with Negative Profit')
plt.xlabel('Sub-Category')
plt.ylabel('Average Value')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
#Calculate the average discount for each sub-category
avg_discount_per_subcat = df.groupby('Sub-Category')['Discount'].mean()

# %%
#Analyze the impact of discount on Sales and Profit

#Scatter plot to visualize the relationship between Sales and Discount
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Discount', y='Sales', data=df)
plt.title('Sales vs. Discount')
plt.xlabel('Discount')
plt.ylabel('Sales')
plt.show()

# %%
# Scatter plot to visualize the relationship between Profit and Discount
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Discount', y='Profit', data=df)
plt.title('Profit vs. Discount')
plt.xlabel('Discount')
plt.ylabel('Profit')
plt.show()

# %%
#Compare discount levels for profitable and non-profitable transactions

# Create a new column to categorize transactions as profitable or non-profitable
df['Profitable'] = df['Profit'] >= 0

# %%
# Box plot to compare discount levels for profitable and non-profitable transactions
plt.figure(figsize=(10, 6))
sns.boxplot(x='Profitable', y='Discount', data=df)
plt.title('Discount Distribution for Profitable and Non-Profitable Transactions')
plt.xlabel('Profitable')
plt.ylabel('Discount')
plt.xticks([0, 1], ['Non-Profitable', 'Profitable'])
plt.show()
